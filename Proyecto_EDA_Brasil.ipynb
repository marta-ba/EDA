# %% [markdown]
# # Análisis de Ingresos Públicos Brasil

# %%
# cargo librerías
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import googletrans
from googletrans import Translator
from src import soporte_limpieza as sl

# %%
sl.traducir_columnas_y_guardar("datos-2021.csv", "BD/datos-2021-es.csv")
# Out:
# Archivo traducido y guardado en: BD/datos-2021-es.csv
#         Código de órganos más alto  \
# 0                            63000
# 1                            63000
# 2                            37000
# 3                            22000
# 4                            22000
# ...                            ...
# 134588                       20000
# 134589                       20000
# 134590                       20000
# 134591                       20000
# 134592                       20000
#
#                                       Nombre Superior  Código corporal  \
# 0                            Advocacia-Geral da União            63000
# 1                            Advocacia-Geral da União            63000
# 2                        Controladoria-Geral da União            37000
# 3       Ministério da Agricultura, Pecuária e Abastec            22211
# 4       Ministério da Agricultura, Pecuária e Abastec            22211
# ...                                               ...              ...
# 134588                       Presidência da República            24208
# 134589                       Presidência da República            24208
# 134590                       Presidência da República            24208
# 134591                       Presidência da República            24208
# 134592                       Presidência da República            24208
#
#                                          Órgano de nombre  \
# 0       Advocacia-Geral da União - Unidades com víncul...
# 1       Advocacia-Geral da União - Unidades com víncul...
# 2       Controladoria-Geral da União - Unidades com ví...
# 3                     Companhia Nacional de Abastecimento
# 4                     Companhia Nacional de Abastecimento
# ...                                                   ...
# 134588     Instituto Nacional de Tecnologia da Informação
# 134589     Instituto Nacional de Tecnologia da Informação
# 134590     Instituto Nacional de Tecnologia da Informação
# 134591     Instituto Nacional de Tecnologia da Informação
# 134592     Instituto Nacional de Tecnologia da Informação
#
#         Código de la unidad de gestión  \
# 0                               110060
# 1                               110060
# 2                               370001
# 3                               135100
# 4                               135100
# ...                                ...
# 134588                          243001
# 134589                          243001
# 134590                          243001
# 134591                          243001
# 134592                          243001
#
#                        Nombre de gestión de la unidad  Categoría económica  \
# 0       COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Receitas de Capital
# 1       COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU   Receitas Correntes
# 2                    DIRETORIA DE GESTAO INTERNA(CGU)  Receitas de Capital
# 3                 COMPANHIA NACIONAL DE ABASTECIMENTO   Receitas Correntes
# 4                 COMPANHIA NACIONAL DE ABASTECIMENTO   Receitas Correntes
# ...                                               ...                  ...
# 134588  INSTITUTO NAC.DE TECNOLOGIA DA INFORMACAO ITI  Receitas de Capital
# 134589  INSTITUTO NAC.DE TECNOLOGIA DA INFORMACAO ITI   Receitas Correntes
# 134590  INSTITUTO NAC.DE TECNOLOGIA DA INFORMACAO ITI   Receitas Correntes
# 134591  INSTITUTO NAC.DE TECNOLOGIA DA INFORMACAO ITI   Receitas Correntes
# 134592  INSTITUTO NAC.DE TECNOLOGIA DA INFORMACAO ITI   Receitas Correntes
#
#                         Ingresos de origen  \
# 0                     Operações de Crédito
# 1       Receitas Correntes - a classificar
# 2                     Operações de Crédito
# 3                      Receita de Serviços
# 4                      Receita de Serviços
# ...                                    ...
# 134588                Operações de Crédito
# 134589                 Receita de Serviços
# 134590                 Receita de Serviços
# 134591                 Receita de Serviços
# 134592                 Receita de Serviços
#
#                                 Especies de ingresos  \
# 0             Operações de crédito - mercado interno
# 1                 Receitas Correntes - a classificar
# 2             Operações de crédito - mercado interno
# 3       Serviços Administrativos e Comerciais Gerais
# 4       Serviços Administrativos e Comerciais Gerais
# ...                                              ...
# 134588        Operações de crédito - mercado interno
# 134589  Serviços Administrativos e Comerciais Gerais
# 134590  Serviços Administrativos e Comerciais Gerais
# 134591  Serviços Administrativos e Comerciais Gerais
# 134592  Serviços Administrativos e Comerciais Gerais
#
#                                               Detalle  \
# 0        TITULOS DE RESPONS.TES.NAC.-MERC.INT.-PRINC.
# 1                  Receitas Correntes - a classificar
# 2        TITULOS DE RESPONS.TES.NAC.-MERC.INT.-PRINC.
# 3       SERV.ADMINISTRAT.E COMERCIAIS GERAIS-MUL.JUR.
# 4       SERV.ADMINISTRAT.E COMERCIAIS GERAIS-MUL.JUR.
# ...                                               ...
# 134588   TITULOS DE RESPONS.TES.NAC.-MERC.INT.-PRINC.
# 134589   SERV.DE REGIST.,CERTIF.E FISCALIZ.-PRINCIPAL
# 134590   SERV.DE REGIST.,CERTIF.E FISCALIZ.-PRINCIPAL
# 134591   SERV.DE REGIST.,CERTIF.E FISCALIZ.-PRINCIPAL
# 134592   SERV.DE REGIST.,CERTIF.E FISCALIZ.-PRINCIPAL
#
#        Valor esperado actualizado Valor lanzado       Valor Porcentaje  \
# 0                   2224034904,00          0,00        0,00       0,00
# 1                            0,00          0,00        0,00       0,00
# 2                    608888110,00          0,00        0,00       0,00
# 3                            0,00          0,00      160,25       0,00
# 4                            0,00          0,00      511,43       0,00
# ...                           ...           ...         ...        ...
# 134588                16940891,00          0,00        0,00       0,00
# 134589                       0,00          0,00      372,90       0,00
# 134590                  200000,00          0,00        0,00       0,00
# 134591                       0,00          0,00  1000000,00       0,00
# 134592                       0,00          0,00  1000000,00       0,00
#
#        Fecha de lanzamiento  Ejercicio anual
# 0                23/04/2021             2021
# 1                16/04/2021             2021
# 2                23/04/2021             2021
# 3                26/01/2021             2021
# 4                16/03/2021             2021
# ...                     ...              ...
# 134588           23/04/2021             2021
# 134589           22/11/2021             2021
# 134590           23/04/2021             2021
# 134591           10/05/2021             2021
# 134592           23/03/2021             2021
#
# [134593 rows x 16 columns]
